# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Libro1.csv",sep=",")

# %%
df
# Out:
#         Name  D _M14  D _SBF  D_lit  ${M}_{K}^{2\mathrm{MASS}}$  \
# 0     NGC 57    76.3    66.9   66.8                      -25.75
# 1    NGC 315    70.3    68.1   70.0                      -26.30
# 2    NGC 708    69.0    61.5   68.5                      -25.65
# 3    NGC 997    90.4    83.7   90.4                      -25.40
# 4   NGC 1453    56.4    51.2   51.0                      -25.67
# 5        NaN    56.4    51.2   51.0                      -25.67
# 6        NaN    56.4    51.2   56.4                      -25.67
# 7   NGC 1600    63.8    71.7   64.0                      -25.99
# 8   NGC 1684    63.5    62.8   62.8                      -25.34
# 9   NGC 2693    74.4    71.0   71.0                      -25.76
# 10       NaN    74.4    71.0   71.0                      -25.76
# 11       NaN    74.4    71.0   71.0                      -25.76
# 12  NGC 3842    99.4    87.5   98.4                      -25.91
# 13  NGC 4472    16.7    16.7   17.1                      -25.72
# ...
